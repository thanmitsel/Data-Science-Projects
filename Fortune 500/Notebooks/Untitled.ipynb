# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fortune = pd.read_csv('fortune1000 2018-final.csv', header = 0, encoding = 'latin-1')

# %%
fortune['Revenues ($M)'] = fortune['Revenues ($M)'].map(lambda x: float(x.replace(',', '').strip('$')))

# %%
fortune.loc[901:1000].plot('title', 'Revenues ($M)', kind='bar', figsize = (16, 5))

# %%
fortune
# Out:
#      rank                                   title Previous Rank  \
# 0       1                                 Walmart             1
# 1       2                             Exxon Mobil             4
# 2       3                      Berkshire Hathaway             2
# 3       4                                   Apple             3
# 4       5                      UnitedHealth Group             6
# 5       6                                McKesson             5
# 6       7                              CVS Health             7
# 7       8                              Amazon.com            12
# 8       9                                    AT&T             9
# 9      10                          General Motors             8
# 10     11                              Ford Motor            10
# 11     12                       AmerisourceBergen            11
# 12     13                                 Chevron            19
# 13     14                         Cardinal Health            15
# ...

# %%
fortune['title'].loc[fortune['title'].str.contains('&')].values
# Out:
# array(['AT&T', 'Johnson & Johnson', 'Procter & Gamble', 'PG& E Corp.',
#        'Goodyear Tire & Rubber', 'Marsh & McLennan',
#        'Stanley Black & Decker', 'Bed Bath & Beyond', 'BB& T Corp.',
#        'Reliance Steel & Aluminum', 'Owens & Minor',
#        'Air Products & Chemicals', 'R.R. Donnelley & Sons',
#        'American Axle & Manufacturing', 'S& P Global', 'M& T Bank Corp.',
#        'Western & Southern Financial', 'Host Hotels & Resorts',
#        'Fortune Brands Home & Security', 'Telephone & Data Systems',
#        'Smart & Final Stores', 'Leggett & Platt', 'Barnes & Noble',
#        'Church & Dwight', 'Abercrombie & Fitch',
#        'International Flavors & Fragrances', 'KapStone Paper & Packaging',
#        'H& R Block', 'Cooper Tire & Rubber', 'Park Hotels & Resorts',
#        'Genesee & Wyoming', 'Central Garden & Pet', 'Brown & Brown',
#        'Barnes & Noble Education'], dtype=object)

# %%
a= float(a)

# %%
a
# Out:
# 2
